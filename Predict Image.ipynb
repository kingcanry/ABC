# %%
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.models import load_model
import matplotlib.pyplot as plt
import numpy as np
import cv2
# Out:
# WARNING:tensorflow:From c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to c:\users\admin\appdata\local\temp\pip-req-build-dst14eas
#   Resolved https://www.github.com/keras-team/keras-contrib.git to commit 3fc5ef709e061416f4bc8a92ca3750c824b5d2b0
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: keras in c:\users\admin\anaconda3\lib\site-packages (from keras-contrib==2.0.8) (2.15.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py): started
#   Building wheel for keras-contrib (setup.py): finished with status 'done'
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-py3-none-any.whl size=101663 sha256=a9038883a2870e1b6b4b67417ce1610938d34e143ac55f883fcd2d57953d38c2
#   Stored in directory: C:\Users\Admin\AppData\Local\Temp\pip-ephem-wheel-cache-n6bnr41j\wheels\51\5f\dc\dade7fdf81085b847dde4bd2fa307f2e0f67a26400031d0c27
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8
#   Running command git clone --filter=blob:none --quiet https://www.github.com/keras-team/keras-contrib.git 'C:\Users\Admin\AppData\Local\Temp\pip-req-build-dst14eas'
#   warning: redirecting to https://github.com/keras-team/keras-contrib.git/

# %%
# Import InstanceNormalization from keras_contrib.layers
from keras_contrib.layers import InstanceNormalization

# Load the model with custom_objects
g_model = load_model('Models/Pixel[02]_Context[08]/g_model.h5', custom_objects={'InstanceNormalization': InstanceNormalization})

# Rest of your code remains unchanged

# load and resize the image
img = load_img('Dataset/CUHK/Testing sketch/f-039-01-sz1.jpg', target_size=(256, 256))
target = cv2.cvtColor(cv2.imread('Dataset/CUHK/Testing photo/f-039-01.jpg'), cv2.COLOR_BGR2RGB)

# convert to numpy array
img = img_to_array(img)
norm_img = (img.copy() - 127.5) / 127.5

g_img = g_model.predict(np.expand_dims(norm_img, 0))[0]
g_img = g_img * 127.5 + 127.5

img = cv2.resize(img, (200, 250))
g_img = cv2.resize(g_img, (200, 250))

f = plt.figure(num=None, figsize=(12, 6), dpi=80)
ax1 = f.add_subplot(1,3, 1)
plt.imshow(img.astype('uint8'))
ax2 = f.add_subplot(1,3, 2)
plt.imshow(g_img.astype('uint8'))
ax3 = f.add_subplot(1,3, 3)
plt.imshow(target.astype('uint8'))
ax1.set_title('Sketch')
ax2.set_title('Generated Image')
ax3.set_title('Target Image')

plt.show(block=True)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 1s 843ms/step

# %%
# Import InstanceNormalization from keras_contrib.layers
from keras_contrib.layers import InstanceNormalization

# Load the model with custom_objects
g_model = load_model('Models/Pixel[02]_Context[08]/g_model.h5', custom_objects={'InstanceNormalization': InstanceNormalization})

# Rest of your code remains unchanged

# load and resize the image
img = load_img('Dataset/CUHK/Testing sketch/m1-041-01-sz1.jpg', target_size=(256, 256))
target = cv2.cvtColor(cv2.imread('Dataset/CUHK/Testing photo/m1-041-01.jpg'), cv2.COLOR_BGR2RGB)

# convert to numpy array
img = img_to_array(img)
norm_img = (img.copy() - 127.5) / 127.5

g_img = g_model.predict(np.expand_dims(norm_img, 0))[0]
g_img = g_img * 127.5 + 127.5

img = cv2.resize(img, (200, 250))
g_img = cv2.resize(g_img, (200, 250))

f = plt.figure(num=None, figsize=(12, 6), dpi=80)
ax1 = f.add_subplot(1,3, 1)
plt.imshow(img.astype('uint8'))
ax2 = f.add_subplot(1,3, 2)
plt.imshow(g_img.astype('uint8'))
ax3 = f.add_subplot(1,3, 3)
plt.imshow(target.astype('uint8'))
ax1.set_title('Sketch')
ax2.set_title('Generated Image')
ax3.set_title('Target Image')

plt.show(block=True)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 1s 1s/step

# %%
# Import InstanceNormalization from keras_contrib.layers
from keras_contrib.layers import InstanceNormalization

# Load the model with custom_objects
g_model = load_model('Models/Pixel[02]_Context[08]/g_model.h5', custom_objects={'InstanceNormalization': InstanceNormalization})

# Rest of your code remains unchanged

# load and resize the image
img = load_img('Dataset/CUHK/Testing sketch/m1-030-01-sz1.jpg', target_size=(256, 256))
target = cv2.cvtColor(cv2.imread('Dataset/CUHK/Testing photo/m1-030-01.jpg'), cv2.COLOR_BGR2RGB)

# convert to numpy array
img = img_to_array(img)
norm_img = (img.copy() - 127.5) / 127.5

g_img = g_model.predict(np.expand_dims(norm_img, 0))[0]
g_img = g_img * 127.5 + 127.5

img = cv2.resize(img, (200, 250))
g_img = cv2.resize(g_img, (200, 250))

f = plt.figure(num=None, figsize=(12, 6), dpi=80)
ax1 = f.add_subplot(1,3, 1)
plt.imshow(img.astype('uint8'))
ax2 = f.add_subplot(1,3, 2)
plt.imshow(g_img.astype('uint8'))
ax3 = f.add_subplot(1,3, 3)
plt.imshow(target.astype('uint8'))
ax1.set_title('Sketch')
ax2.set_title('Generated Image')
ax3.set_title('Target Image')

plt.show(block=True)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 1s 806ms/step
